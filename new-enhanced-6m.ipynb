# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import NearestNeighbors
from collections import Counter

# %%
def weighted_euclidean_distance(p, q, weights):
    return np.sqrt(np.sum(weights * (p - q) ** 2))

# %%
def weighted_adasyn(X, y, beta=0.8, k=5, weights=None, random_state=None):
    np.random.seed(random_state)
    
    # Identify classes and counts
    class_counts = Counter(y)
    if len(class_counts) < 2:
        return X.copy(), y.copy()
        
    major_class = max(class_counts, key=class_counts.get)
    minor_class = min(class_counts, key=class_counts.get)
    n_major = class_counts[major_class]
    n_minor = class_counts[minor_class]

    if n_minor >= n_major * beta:
        return X.copy(), y.copy()

    G = int(n_major * beta) - n_minor
    if G <= 0:
        return X.copy(), y.copy()

    # --- Weighted Neighbor Search Setup ---
    X_min = X[y == minor_class]
    
    if weights is not None:
        if weights.shape[0] != X.shape[1]:
            raise ValueError("Weights must have the same dimension as the number of features.")
        sqrt_weights = np.sqrt(weights)
        
        # Scale features for distance calculation (Weighted Euclidean Distance)
        X_scaled = X * sqrt_weights
        X_min_scaled = X_min * sqrt_weights
    else:
        X_scaled = X
        X_min_scaled = X_min
        
    # Find neighbors among ALL samples (to calculate ri)
    nn = NearestNeighbors(n_neighbors=k + 1).fit(X_scaled)

    # --- ADASYN Ratio Calculation ---
    distances, indices = nn.kneighbors(X_min_scaled)
    ri_list = []
    
    for i in range(n_minor):
        neighbor_indices = indices[i, 1:] 
        neighbor_labels = y[neighbor_indices]
        delta_i = np.sum(neighbor_labels == major_class)
        ri = delta_i / k
        ri_list.append(ri)
        
    ri_array = np.array(ri_list)
    sum_ri = np.sum(ri_array)
    
    if sum_ri == 0:
        # Fallback if no minority samples are near majority samples
        ri_hat = np.full(len(ri_array), 1/len(ri_array))
    else:
        ri_hat = ri_array / sum_ri
        
    # Number of samples to generate for each minority instance
    gi_array = np.round(G * ri_hat).astype(int)
    # Recalculate G based on rounded values
    G = np.sum(gi_array) 

    # --- Synthetic Sample Generation ---
    X_synthetic = []
    nn_minority = NearestNeighbors(n_neighbors=k + 1).fit(X_min_scaled)
    
    for i in range(n_minor):
        xi = X_min[i]
        n_to_generate = gi_array[i]
        
        if n_to_generate > 0:
            _, min_indices = nn_minority.kneighbors([X_min_scaled[i]])
            minority_neighbor_indices = min_indices[0, 1:] 
            
            if len(minority_neighbor_indices) == 0:
                continue
                
            if len(minority_neighbor_indices) < n_to_generate:
                neighbor_choices = np.random.choice(minority_neighbor_indices, n_to_generate, replace=True)
            else:
                neighbor_choices = np.random.choice(minority_neighbor_indices, n_to_generate, replace=False)
                
            for neighbor_idx in neighbor_choices:
                xj = X_min[neighbor_idx]
                lam = np.random.rand()
                
                # Calculation stays in original feature space to prevent "feature drift"
                # while xj was chosen using weighted distances.
                diff = xj - xi
                
                # Generate synthetic sample: x_new = xi + lam * (xj - xi)
                synthetic_sample = xi + lam * diff
                X_synthetic.append(synthetic_sample)
            
    if len(X_synthetic) == 0:
        return X.copy(), y.copy()
        
    X_synthetic = np.array(X_synthetic)
    y_synthetic = np.full(X_synthetic.shape[0], minor_class)
    
    X_resampled = np.vstack([X, X_synthetic])
    y_resampled = np.concatenate([y, y_synthetic])

    return X_resampled, y_resampled

# %%
df = pd.read_csv("onlinefraud.csv")

# %%
for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df = df.sample(6000000, random_state=42)

# %%
X = df.drop("isFraud", axis=1).values
y = df["isFraud"].values

# %%
feature_weights = np.ones(X.shape[1]) 
X_resampled, y_resampled = weighted_adasyn(X, y, beta=0.8, k=5, weights=feature_weights)

print("Before ADASYN:", np.bincount(y))
print("After ADASYN :", np.bincount(y_resampled))
# Out:
# Before ADASYN: [5992248    7752]
# After ADASYN : [5992248 4794643]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.3, stratify=y_resampled, random_state=42
)

# %%
cart = DecisionTreeClassifier(
    criterion="gini",       # standard Gini (approximating Regularized Gini)
    max_depth=5,            # limits tree growth (stability)
    min_samples_split=10,   
    min_samples_leaf=5,    
    ccp_alpha=0.001,        # cost-complexity pruning (acts like λ·Complexity(T))
    random_state=42
)

# %%
ada_cart = AdaBoostClassifier(
    estimator=cart,
    n_estimators=50,
    learning_rate=0.5,
    random_state=42
)

# %%
ada_cart.fit(X_train, y_train)
y_pred = ada_cart.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9872558302235923

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99   1797675
#            1       0.98      0.99      0.99   1438393
#
#     accuracy                           0.99   3236068
#    macro avg       0.99      0.99      0.99   3236068
# weighted avg       0.99      0.99      0.99   3236068

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()
df_report = df_report.drop(columns=['support'])
df_plot = df_report.iloc[[0, 1]][['precision', 'recall', 'f1-score']]

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(
    df_plot,
    annot=True,            # Show the numeric value in each cell
    fmt=".2f",             # Format to 2 decimal places
    cmap="Greens",         
    cbar=True,             # Display the color bar
    linewidths=.5,         # Add lines for separation
)
# Out:
# <Axes: >

# %%
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[1764493   33182]
#  [   8059 1430334]]

# %%
scores = cross_val_score(ada_cart, X, y, cv=5, scoring='f1')  
print(f"Cross-validation scores: {scores}")
print(f"Mean score: {np.mean(scores)}")
print(f"Variance: {np.var(scores)}")
# Out:
# Cross-validation scores: [0.84788214 0.84923525 0.84253127 0.84846266 0.85559175]
# Mean score: 0.8487406146727487
# Variance: 1.731057200150427e-05

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(y=scores, color='lightblue', width=0.3)
sns.stripplot(y=scores, color='darkblue', size=8, jitter=False)

plt.title('Cross-Validation F1 Score Distribution', fontsize=14)
plt.ylabel('F1 Score', fontsize=12)
plt.xticks([]) # Hide x-axis labels since there's only one box
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Optional: Annotate the mean and variance on the plot
mean_score = np.mean(scores)
var_score = np.var(scores)
plt.text(0.1, mean_score, 
         f'Mean: {mean_score:.4f}\nVariance: {var_score:.5f}', 
         ha='left', va='center', 
         bbox=dict(facecolor='white', alpha=0.7))

plt.show()
